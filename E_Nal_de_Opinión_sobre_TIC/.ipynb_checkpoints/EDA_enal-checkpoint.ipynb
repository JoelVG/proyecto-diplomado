# %%
import pandas as pd
import json
pd.options.display.max_colwidth = 100

# %%
df = pd.read_csv("enal_final_corregido.csv", delimiter=",", low_memory=False)
df.head()
# Out:
#    NUMBOL  Tipo  P1  P2  P3  P1A  P1B  P1C  P1D  P1E  ...  P156J  P156K  P157  \
# 0       1     1  18   1   1  NaN  NaN  NaN  NaN  NaN  ...      2      2     5
# 1       2     1  21   1   1  NaN  NaN  NaN  NaN  NaN  ...      2      2     7
# 2       3     1  54   1   1  NaN  NaN  NaN  NaN  NaN  ...      2      2     4
# 3       4     1  30   1   1  NaN  NaN  NaN  NaN  NaN  ...      2      2     4
# 4       5     1  16   1   1  NaN  NaN  NaN  NaN  NaN  ...      2      2     4
#
#    P158  P159    P160  CodP160    Ponderador5536    Ponderador5033  Nse
# 0     1     1  La Paz       33  1,66029585357411  2,55437533673007    3
# 1     1     1  La Paz       33  1,66029585357411  2,55437533673007    4
# 2     1     1  La Paz       33  1,66029585357411  2,55437533673007    2
# 3     1     1  La Paz       33  1,66029585357411  2,55437533673007    2
# 4     1     1  La Paz       33  1,66029585357411  2,55437533673007    2
#
# [5 rows x 451 columns]

# %%
# # Cambiamos el index a numbol
# df.set_index("NUMBOL", inplace=True, verify_integrity=True)
# df.head()

# %% [markdown]
# ### Cargamos el archivo json generado previamente y las preguntas que nos ayudarán con este análisis.

# %% [markdown]
# ### Schema del archivo json por pregunta
# ```
#  {
#     "nq": "3.", // Número de pregunta. Ejm. P3
#     "question": "¿Cuándo fue la última vez que navegó en Internet o estuvo co nectado a las redes sociales?", // Pregunta
#     "qtype": "Numérico", // Tipo de respuesta obtenido
#     "rtype": "Nominal", // Tipo de respuesta que representa
#     "options": { // Opciones de respuesta qtype: rtype
#         "1": "Hace 7 días o menos",
#         "2": "Entre 8 a 15 días",
#         "3": "Entre 16 a 30 días",
#         "4": "Hace más de 30 días"
#     }
#  }
# ```

# %%
# Cargamos el diccionario de datos json que generamos previamente a un dataframe
json_df = pd.read_json("data_dict_e_nal2.json", encoding="utf-8", orient="records")
json_df.head()
# Out:
#    nq  \
# 0   2
# 1   3
# 2   4
# 3   5
# 4   6
#
#                                                                                        question  \
# 0                                                           ¿Me podría decir su edad por favor?
# 1  ¿Usted ha navegado por Internet o se ha conectado a alguna r ed social a través de Internet?
# 2    ¿Cuándo fue la última vez que navegó en Internet o estuvo co nectado a las redes sociales?
# 3                ¿Cuáles son las razones por las cuales no se conecta a Inte rnet regularmente?
# 4                ¿Cuáles son las razones por las cuales no se conecta a Inte rnet regularmente?
#
#       qtype    rtype  \
# 0  Numérico   Escala
# 1  Numérico  Nominal
# 2  Numérico  Nominal
# 3  Numérico  Nominal
# 4  Numérico  Nominal
#
#                                                                                                options
# 0                                                                                                   {}
# 1                                                                               {'1': 'Si', '2': 'No'}
# 2  {'1': 'Hace 7 días o menos', '2': 'Entre 8 a 15 días', '3': 'Entre 16 a 30 días', '4': 'Hace más...
# 3  {'1': 'No existe el servicio en el barrio/localidad', '2': 'El costo del servicio alto', '3': 'N...
# 4  {'1': 'No existe el servicio en el barrio/localidad', '2': 'El costo del servicio alto', '3': 'N...

# %% [markdown]
# ### Siguientes consideraciones del diccionario de datos que generamos:
# * nq indica la posición de la pregunta a la cual indica la respuesta de los datos. Ejm. nq=2 indica la pregunta para la respuesta en pa posición 2 del dataset de respuestas.
# * Notamos que algunas preguntas [questions] contienen palabras mal escritas. Justamente después del caracter 60.

# %%
# Cambiamos el index a nq
json_df.set_index("nq", inplace=True, verify_integrity=True)
json_df.head()
# Out:
#                                                                                         question  \
# nq
# 2                                                            ¿Me podría decir su edad por favor?
# 3   ¿Usted ha navegado por Internet o se ha conectado a alguna r ed social a través de Internet?
# 4     ¿Cuándo fue la última vez que navegó en Internet o estuvo co nectado a las redes sociales?
# 5                 ¿Cuáles son las razones por las cuales no se conecta a Inte rnet regularmente?
# 6                 ¿Cuáles son las razones por las cuales no se conecta a Inte rnet regularmente?
#
#        qtype    rtype  \
# nq
# 2   Numérico   Escala
# 3   Numérico  Nominal
# 4   Numérico  Nominal
# 5   Numérico  Nominal
# 6   Numérico  Nominal
#
#                                                                                                 options
# nq
# 2                                                                                                    {}
# 3                                                                                {'1': 'Si', '2': 'No'}
# 4   {'1': 'Hace 7 días o menos', '2': 'Entre 8 a 15 días', '3': 'Entre 16 a 30 días', '4': 'Hace más...
# 5   {'1': 'No existe el servicio en el barrio/localidad', '2': 'El costo del servicio alto', '3': 'N...
# 6   {'1': 'No existe el servicio en el barrio/localidad', '2': 'El costo del servicio alto', '3': 'N...

# %% [markdown]
# ### Mostramos las preguntas seleccionadas para el análisis de este dataset.
# ### Se descubren preguntas que no se encuentran en nuestro diccionario de datos así que se procede a agregarlas de manera manual

# %%
q_code = []
df_columns = list(df.columns)
missing_qi = []
with open("main_qa.txt", "r") as f:
    q_code = [qc.strip().upper() for qc in f]
    # Imprimimos las preguntas seleccionadas
    for qc in q_code:
        index_q = df_columns.index(qc)
        try:
            question = json_df.loc[index_q, "question"]
            print(f"{df.columns[index_q]}: {question}")
        except KeyError:
            print(f"ERROR: Pregunta {qc} (index: {index_q}) no definida en el diccionario de datos")
            missing_qi.append(index_q)
# Out:
# P1: ¿Me podría decir su edad por favor?
# P2: ¿Usted ha navegado por Internet o se ha conectado a alguna r ed social a través de Internet?
# P1A: ¿Cuáles son las razones por las cuales no se conecta a Inte rnet regularmente?
# P1B: ¿Cuáles son las razones por las cuales no se conecta a Inte rnet regularmente?
# P1C: ¿Cuáles son las razones por las cuales no se conecta a Inte rnet regularmente?
# P1D: ¿Cuáles son las razones por las cuales no se conecta a Inte rnet regularmente?
# P6: ¿Tiene computadora de escritorio, computadora portátil o tab let en su casa?
# P11A: ¿Qué usos le da usted a estos equipos?
# P11B: ¿Qué usos le da usted a estos equipos?
# P11C: ¿Qué usos le da usted a estos equipos?
# P11F: ¿Qué usos le da usted a estos equipos?
# P27A: ¿Para qué usa mayormente esta conexión a Internet?Valores válidos P27B
# P27B: ¿Para qué usa mayormente esta conexión a Internet?
# P27C: ¿Para qué usa mayormente esta conexión a Internet?
# P27D: ¿Tiene celular?
# P27E: ¿Para qué usa mayormente esta conexión a Internet?
# P27F: ¿Para qué usa mayormente esta conexión a Internet?
# P27G: Otro
# ERROR: Pregunta P28 (index: 59) no definida en el diccionario de datos
# P37: ¿Cuánto paga al mes en promedio por el servicio de Internet ?
# P43: ¿De lunes a viernes, en qué horarios se conecta a Internet?
# ERROR: Pregunta P46A (index: 147) no definida en el diccionario de datos
# ERROR: Pregunta P46B (index: 148) no definida en el diccionario de datos
# ERROR: Pregunta P46C (index: 149) no definida en el diccionario de datos
# P46D: ¿Qué tipo de información busca en Internet?
# ERROR: Pregunta P46E (index: 150) no definida en el diccionario de datos
# ERROR: Pregunta P46F (index: 151) no definida en el diccionario de datos
# ERROR: Pregunta P46G (index: 152) no definida en el diccionario de datos
# ERROR: Pregunta P46H (index: 153) no definida en el diccionario de datos
# P46I: Otro
# P47A: ¿Qué tipo de información busca en Internet?
# P47B: ¿Qué tipo de información busca en Internet?
# P47C: ¿Qué tipo de información busca en Internet?
# P47D: ¿Qué tipo de información busca en Internet?
# P47E: ¿Qué tipo de información busca en Internet?
# P47F: ¿Cuáles son las tres páginas web nacionales que más visita?
# P47G: ¿Qué tipo de información busca en Internet?
# P47H: ¿Qué tipo de información busca en Internet?
# P47I: Otro
# P63A: ¿Usualmente realiza trámites en estas páginas web?
# P63B: ¿Según su opinión, qué información de las instituciones púb licas debería estar disponible en Internet en primer lugar?
# P68: ¿Ha realizado algún curso, diplomado o maestría por Interne t?
# P131A: Entretenimiento?
# P131B: Entretenimiento?
# P131C: Entretenimiento?
# P148: ¿En qué idioma aprendió a hablar?
# P149: ¿En qué idioma aprendió a hablar? (Otro Nativo)
# P152: Otro

# %%
# Índice de preguntas faltantes
missing_qi
# Out:
# [59, 147, 148, 149, 150, 151, 152, 153]

# %% [markdown]
# ### Se corrige manualmente las preguntas faltantes exceptuando la pregunta P28 con índice 59 dado que se considera de baja relevancia.
#
# Posteriormente procedemos a reducir las columnas de nuestro dataset a solo aquellas respuestas de nuestro interés,
# también filtramos las respuestas únicamente de estudiantes (columna P152, opción 6: Estudiante)
#
#  Nota: Existe un efecto visual para las preguntas mostradas. No se corrigió por cuestiones de tiempo pero no afecta en lo absoluto en el dataset
#  resultante, ya que la lista de preguntas que se ven a continuación son con el único fin de mostrar las preguntas que se están seleccionando.

# %%
q_code = []
df_columns = list(df.columns)
missing_qi = []
with open("main_qa.txt", "r") as f:
    q_code = [qc.strip().upper() for qc in f]
    # Imprimimos las preguntas seleccionadas
    for qc in q_code:
        index_q = df_columns.index(qc)
        try:
            question = json_df.loc[index_q, "question"]
            print(f"{df.columns[index_q]}: {question}")
        except KeyError:
            print(f"ERROR: Pregunta {qc} (index: {index_q}) no definida en el diccionario de datos")
            missing_qi.append(index_q)
# Out:
# P1: ¿Me podría decir su edad por favor?
# P2: ¿Usted ha navegado por Internet o se ha conectado a alguna r ed social a través de Internet?
# P1A: ¿Cuáles son las razones por las cuales no se conecta a Inte rnet regularmente?
# P1B: ¿Cuáles son las razones por las cuales no se conecta a Inte rnet regularmente?
# P1C: ¿Cuáles son las razones por las cuales no se conecta a Inte rnet regularmente?
# P1D: ¿Cuáles son las razones por las cuales no se conecta a Inte rnet regularmente?
# P6: ¿Tiene computadora de escritorio, computadora portátil o tab let en su casa?
# P11A: ¿Qué usos le da usted a estos equipos?
# P11B: ¿Qué usos le da usted a estos equipos?
# P11C: ¿Qué usos le da usted a estos equipos?
# P11F: ¿Qué usos le da usted a estos equipos?
# P27A: ¿Para qué usa mayormente esta conexión a Internet?Valores válidos P27B
# P27B: ¿Para qué usa mayormente esta conexión a Internet?
# P27C: ¿Para qué usa mayormente esta conexión a Internet?
# P27D: ¿Tiene celular?
# P27E: ¿Para qué usa mayormente esta conexión a Internet?
# P27F: ¿Para qué usa mayormente esta conexión a Internet?
# P27G: Otro
# P37: ¿Cuánto paga al mes en promedio por el servicio de Internet ?
# P43: ¿De lunes a viernes, en qué horarios se conecta a Internet?
# P46A: ¿Cuáles de las siguientes actividades realiza con más frecuencia en el Internet?
# P46B: ¿Cuáles de las siguientes actividades realiza con más frecuencia en el Internet?
# P46C: ¿Cuáles de las siguientes actividades realiza con más frecuencia en el Internet?
# P46D: ¿Qué tipo de información busca en Internet?
# P46E: ¿Cuáles de las siguientes actividades realiza con más frecuencia en el Internet?
# P46F: ¿Cuáles de las siguientes actividades realiza con más frecuencia en el Internet?
# P46G: ¿Cuáles de las siguientes actividades realiza con más frecuencia en el Internet?
# P46H: ¿Cuáles de las siguientes actividades realiza con más frecuencia en el Internet?
# P46I: Otro
# P47A: ¿Qué tipo de información busca en Internet?
# P47B: ¿Qué tipo de información busca en Internet?
# P47C: ¿Qué tipo de información busca en Internet?
# P47D: ¿Qué tipo de información busca en Internet?
# P47E: ¿Qué tipo de información busca en Internet?
# P47F: ¿Cuáles son las tres páginas web nacionales que más visita?
# P47G: ¿Qué tipo de información busca en Internet?
# P47H: ¿Qué tipo de información busca en Internet?
# P47I: Otro
# P63A: ¿Usualmente realiza trámites en estas páginas web?
# P63B: ¿Según su opinión, qué información de las instituciones púb licas debería estar disponible en Internet en primer lugar?
# P68: ¿Ha realizado algún curso, diplomado o maestría por Interne t?
# P131A: Entretenimiento?
# P131B: Entretenimiento?
# P131C: Entretenimiento?
# P148: ¿En qué idioma aprendió a hablar?
# P149: ¿En qué idioma aprendió a hablar? (Otro Nativo)
# P152: Otro
# P160: Ciudad

# %%
# Generando un nuevo dataframe con respuestas de solo Estudiantes
new_df = df[df['P152'] == 6]
new_df.head()
# Out:
#     NUMBOL  Tipo  P1  P2   P3  P1A  P1B  P1C  P1D  P1E  ...  P156J  P156K  \
# 0        1     1  18   1  1.0  NaN  NaN  NaN  NaN  NaN  ...      2      2
# 4        5     1  16   1  1.0  NaN  NaN  NaN  NaN  NaN  ...      2      2
# 9       10     1  18   1  1.0  NaN  NaN  NaN  NaN  NaN  ...      2      2
# 11      12     1  20   1  3.0  NaN  NaN  NaN  NaN  NaN  ...      1      1
# 17      18     1  18   1  1.0  NaN  NaN  NaN  NaN  NaN  ...      2      2
#
#     P157  P158 P159    P160  CodP160    Ponderador5536    Ponderador5033  Nse
# 0      5     1    1  La Paz       33  1,66029585357411  2,55437533673007    3
# 4      4     1    1  La Paz       33  1,66029585357411  2,55437533673007    2
# 9      6     1    1  La Paz       33  1,66029585357411  2,55437533673007    4
# 11     6     1    1  La Paz       33  1,66029585357411  2,55437533673007    4
# 17     3     1    1  La Paz       33  1,66029585357411  2,55437533673007    1
#
# [5 rows x 451 columns]

# %%
# Filtrando solo las respuestas que nos interesan
new_df = new_df[q_code]
new_df.head(10)
# Out:
#     P1  P2  P1A  P1B  P1C  P1D  P6  P11A  P11B  P11C  ...  P63A  P63B  P68  \
# 0   18   1  NaN  NaN  NaN  NaN   1   4.0   5.0   NaN  ...   1.0   2.0  1.0
# 4   16   1  NaN  NaN  NaN  NaN   2   5.0   NaN   NaN  ...   1.0   2.0  1.0
# 9   18   1  NaN  NaN  NaN  NaN   1   2.0   3.0   4.0  ...   1.0   2.0  2.0
# 11  20   1  NaN  NaN  NaN  NaN   1   2.0   3.0   4.0  ...   2.0   NaN  2.0
# 17  18   1  NaN  NaN  NaN  NaN   2   4.0   5.0   NaN  ...   2.0   NaN  1.0
# 24  19   1  NaN  NaN  NaN  NaN   1   5.0   NaN   NaN  ...   2.0   NaN  1.0
# 25  14   1  NaN  NaN  NaN  NaN   1   2.0   3.0   4.0  ...   2.0   NaN  1.0
# 29  21   1  NaN  NaN  NaN  NaN   1   1.0   2.0   3.0  ...   1.0   1.0  1.0
# 34  18   1  NaN  NaN  NaN  NaN   1   3.0   5.0   NaN  ...   1.0   2.0  2.0
# 38  23   1  NaN  NaN  NaN  NaN   1   1.0   NaN   NaN  ...   1.0   2.0  2.0
#
#     P131A P131B  P131C  P148  P149  P152    P160
# 0     5.0   NaN    NaN     1     3     6  La Paz
# 4     1.0   2.0    NaN     2     2     6  La Paz
# 9     5.0   NaN    NaN     1     3     6  La Paz
# 11    6.0   NaN    NaN     1     6     6  La Paz
# 17    1.0   2.0    6.0     2     3     6  La Paz
# 24    6.0   NaN    NaN     2     3     6  La Paz
# 25    5.0   1.0    NaN     1     2     6  La Paz
# 29    1.0   5.0    NaN     2     3     6  La Paz
# 34    6.0   NaN    NaN     1     3     6  La Paz
# 38    5.0   NaN    NaN     2     6     6  La Paz
#
# [10 rows x 48 columns]

# %%
# Exportamos las columnas que elegimos para el análisis
new_df.to_csv("enal_final_clnd.csv")
